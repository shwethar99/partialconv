# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/UNetSend
# Out:
# /content/drive/My Drive/UNetSend

# %%
# !python setup.py install
# Out:
# /usr/local/lib/python3.7/dist-packages/setuptools/dist.py:672: UserWarning: Usage of dash-separated 'description-file' will not be supported in future versions. Please use the underscore name 'description_file' instead
#   % (opt, underscore_opt))
# running install
# running bdist_egg
# running egg_info
# writing mlfromscratch.egg-info/PKG-INFO
# writing dependency_links to mlfromscratch.egg-info/dependency_links.txt
# writing requirements to mlfromscratch.egg-info/requires.txt
# writing top-level names to mlfromscratch.egg-info/top_level.txt
# adding license file 'LICENSE' (matched pattern 'LICEN[CS]E*')
# reading manifest template 'MANIFEST.in'
# ...
# writing manifest file 'mlfromscratch.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# copying mlfromscratch/deep_learning/loss_functions.py -> build/lib/mlfromscratch/deep_learning
# creating build/bdist.linux-x86_64/egg
# ...

# %%
cd ./mlfromscratch/examples
# Out:
# /content/drive/My Drive/UNetSend/mlfromscratch/examples

# %%
# !python unet_sender.py
# Out:
# (512, 512, 3)
# (1, 3, 128, 128)
#
# +------+
# | UNet |
# +------+
# Input Shape: (3, 128, 128)
# +--------------------+------------+----------------+
# | Layer Type         | Parameters | Output Shape   |
# +--------------------+------------+----------------+
# | Conv2D             | 84         | (3, 128, 128)  |
# | Activation (ReLU)  | 0          | (3, 128, 128)  |
# | BatchNormalization | 98304      | (3, 128, 128)  |
# | Conv2D             | 224        | (8, 128, 128)  |
# | Activation (ReLU)  | 0          | (8, 128, 128)  |
# | BatchNormalization | 262144     | (8, 128, 128)  |
# | Conv2D             | 584        | (8, 128, 128)  |
# | Activation (ReLU)  | 0          | (8, 128, 128)  |
# | BatchNormalization | 262144     | (8, 128, 128)  |
# | MaxPooling2D       | 0          | (8, 64, 64)    |
# | Conv2D             | 1168       | (16, 64, 64)   |
# | Activation (ReLU)  | 0          | (16, 64, 64)   |
# | BatchNormalization | 131072     | (16, 64, 64)   |
# ...
